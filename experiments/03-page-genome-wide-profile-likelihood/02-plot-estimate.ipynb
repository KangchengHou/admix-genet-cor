# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

import numpy as np
import admix
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.transforms as mtrans
import string
import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import json
from scipy.stats import combine_pvalues

# %%
def meta_analysis(effects, se, method="random", weights=None):
    # From Omer Weissbrod
    assert method in ["fixed", "random"]
    d = effects
    variances = se ** 2

    # compute random-effects variance tau2
    vwts = 1.0 / variances
    fixedsumm = vwts.dot(d) / vwts.sum()
    Q = np.sum(((d - fixedsumm) ** 2) / variances)
    df = len(d) - 1
    tau2 = np.maximum(0, (Q - df) / (vwts.sum() - vwts.dot(vwts) / vwts.sum()))

    # defing weights
    if weights is None:
        if method == "fixed":
            wt = 1.0 / variances
        else:
            wt = 1.0 / (variances + tau2)
    else:
        wt = weights

    # compute summtest
    summ = wt.dot(d) / wt.sum()
    if method == "fixed":
        varsum = np.sum(wt * wt * variances) / (np.sum(wt) ** 2)
    else:
        varsum = np.sum(wt * wt * (variances + tau2)) / (np.sum(wt) ** 2)
    ###summtest = summ / np.sqrt(varsum)

    summary = summ
    se_summary = np.sqrt(varsum)

    return summary, se_summary

# %%
SUPP_TABLE_URL = "supp_tables.xlsx"
trait_info = pd.read_excel(SUPP_TABLE_URL, sheet_name="trait-info")
trait_list = trait_info["trait"].values
dict_trait_display_name = {
    row["trait"]: row["display-name"] for _, row in trait_info.iterrows()
}
dict_trait_display_name["a1c"] = r"HbA$_{1c}$"

dict_trait_category = {row.trait: row.category for _, row in trait_info.iterrows()}

# %%
def estimate_rg(est, est_var):
    """
    Estimate the ratio of genetic correlation.
    est: (3, ) numpy array
    est_var (3, 3) variance-covariance matrix
    """
    x, y = est[0], est[1]
    rg = y / x
    # grad = [-y / x^2, 1 / x]
    grad = np.array([-y / (x ** 2), 1 / x])

    def quad_form(x, A):
        return np.dot(np.dot(x.T, A), x)

    return rg, quad_form(grad, est_var[0:2, 0:2])

# %%
df_plot = {
    "trait": [],
    "n_indiv": [],
    "rg": [],
    "rg_stderr": [],
    "snpset": [],
    "hermodel": [],
}

for trait in trait_list:
    for snpset in ["imputed"]:
        for hermodel in ["mafukb", "gcta"]:
            reml_file = f"out/gcta-estimate-jan-27/{trait}.{snpset}.{hermodel}"
            if trait == "total_wbc_cnt":
                reml_file += ".duffy_covar"
            reml_rls = admix.tools.gcta.read_reml(reml_file)
            n_indiv = reml_rls["n"]
            gcta_rg, gcta_rg_var = estimate_rg(
                reml_rls["est"]["Variance"].values, reml_rls["varcov"].values
            )
            gcta_rg_stderr = np.sqrt(gcta_rg_var)
            # fill in data for plotting
            df_plot["trait"].append(trait)
            df_plot["snpset"].append(snpset)
            df_plot["hermodel"].append(hermodel)
            df_plot["n_indiv"].append(n_indiv)

            # REML
            df_plot["rg"].append(gcta_rg)
            df_plot["rg_stderr"].append(gcta_rg_stderr)

df_plot = pd.DataFrame(df_plot)
df_plot["pval"] = stats.norm.cdf((df_plot["rg"] - 1) / df_plot["rg_stderr"])
df_plot["category"] = [dict_trait_category[trait] for trait in df_plot["trait"]]
df_plot["category"] = df_plot["category"].astype("category")

# %%
df_plot
# Out:
#                                trait  n_indiv        rg  rg_stderr   snpset  \
# 0                                crp     8521  0.982904   0.058794  imputed
# 1                                crp     8521  0.993169   0.050401  imputed
# 2                      total_wbc_cnt     8889  0.930436   0.076733  imputed
# 3                      total_wbc_cnt     8889  0.940520   0.068273  imputed
# 4                 mean_corp_hgb_conc     3816  0.885964   0.195627  imputed
# 5                 mean_corp_hgb_conc     3816  0.950120   0.130718  imputed
# 6                       platelet_cnt     8871  0.883233   0.108748  imputed
# 7                       platelet_cnt     8871  0.892714   0.101108  imputed
# 8                                hdl    10248  0.909401   0.092519  imputed
# 9                                hdl    10248  0.922395   0.080796  imputed
# 10                               ldl     9875  0.950779   0.104315  imputed
# 11                               ldl     9875  0.954629   0.094487  imputed
# 12                     triglycerides    10217  0.882079   0.109784  imputed
# 13                     triglycerides    10217  0.902251   0.093608  imputed
# 14                 total_cholesterol    10300  0.696504   0.182694  imputed
# 15                 total_cholesterol    10300  0.707211   0.181475  imputed
# 16  cigs_per_day_excl_nonsmk_updated     7171  0.989965   0.125991  imputed
# 17  cigs_per_day_excl_nonsmk_updated     7171  0.981199   0.118425  imputed
# 18                    coffee_cup_day    11862  1.030606   0.076117  imputed
# 19                    coffee_cup_day    11862  1.028611   0.068056  imputed
# 20                               a1c     1854  1.183164   0.208806  imputed
# 21                               a1c     1854  1.184392   0.235983  imputed
# 22                           insulin     7927  1.038873   0.078180  imputed
# 23                           insulin     7927  1.023553   0.076696  imputed
# 24                           glucose     9937  0.813451   0.276967  imputed
# 25                           glucose     9937  0.743177   0.386242  imputed
# 26                        t2d_status    15014  0.909667   0.137784  imputed
# 27                        t2d_status    15014  0.934917   0.114657  imputed
# 28                       qt_interval     4196  1.065628   0.089850  imputed
# 29                       qt_interval     4196  1.056064   0.085339  imputed
# 30                      qrs_interval     4185  1.155122   0.088907  imputed
# 31                      qrs_interval     4185  1.121948   0.082391  imputed
# 32                       pr_interval     4178  0.903025   0.204259  imputed
# 33                       pr_interval     4178  0.888850   0.222285  imputed
# 34                       systolic_bp    11425  1.101554   0.071436  imputed
# 35                       systolic_bp    11425  1.086655   0.068243  imputed
# 36                      diastolic_bp    11424  1.004098   0.211701  imputed
# 37                      diastolic_bp    11424  0.969757   0.254397  imputed
# 38                      hypertension    17195  0.955916   0.104431  imputed
# 39                      hypertension    17195  0.955709   0.094810  imputed
# 40                   waist_hip_ratio    10307  0.999880   0.085389  imputed
# 41                   waist_hip_ratio    10307  0.989194   0.084149  imputed
# 42                            height    17286  0.920860   0.037441  imputed
# 43                            height    17286  0.923209   0.035440  imputed
# 44                               bmi    17264  0.946773   0.047040  imputed
# 45                               bmi    17264  0.948476   0.042823  imputed
# 46                        egfrckdepi     8261  0.811970   0.162321  imputed
# 47                        egfrckdepi     8261  0.798302   0.170169  imputed
#
#    hermodel      pval           category
# 0    mafukb  0.385608       inflammatory
# 1      gcta  0.446094       inflammatory
# 2    mafukb  0.182317       inflammatory
# 3      gcta  0.191821       inflammatory
# 4    mafukb  0.279971       inflammatory
# 5      gcta  0.351384       inflammatory
# 6    mafukb  0.141470       inflammatory
# 7      gcta  0.144321       inflammatory
# 8    mafukb  0.163730              lipid
# 9      gcta  0.168400              lipid
# 10   mafukb  0.318519              lipid
# 11     gcta  0.315547              lipid
# 12   mafukb  0.141384              lipid
# 13     gcta  0.148186              lipid
# 14   mafukb  0.048334              lipid
# 15     gcta  0.053330              lipid
# 16   mafukb  0.468259          lifestyle
# 17     gcta  0.436929          lifestyle
# 18   mafukb  0.656191          lifestyle
# 19     gcta  0.662907          lifestyle
# 20   mafukb  0.809810           glycemic
# 21     gcta  0.782710           glycemic
# 22   mafukb  0.690485           glycemic
# 23     gcta  0.620618           glycemic
# 24   mafukb  0.250301           glycemic
# 25     gcta  0.253048           glycemic
# 26   mafukb  0.256035           glycemic
# 27     gcta  0.285143           glycemic
# 28   mafukb  0.767432  electrocardiogram
# 29     gcta  0.744398  electrocardiogram
# 30   mafukb  0.959487  electrocardiogram
# 31     gcta  0.930579  electrocardiogram
# 32   mafukb  0.317478  electrocardiogram
# 33     gcta  0.308526  electrocardiogram
# 34   mafukb  0.922430     blood pressure
# 35     gcta  0.897923     blood pressure
# 36   mafukb  0.507723     blood pressure
# 37     gcta  0.452684     blood pressure
# 38   mafukb  0.336464     blood pressure
# 39     gcta  0.320192     blood pressure
# 40   mafukb  0.499438     anthropometric
# 41     gcta  0.448909     anthropometric
# 42   mafukb  0.017270     anthropometric
# 43     gcta  0.015125     anthropometric
# 44   mafukb  0.128916     anthropometric
# 45     gcta  0.114452     anthropometric
# 46   mafukb  0.123354             kidney
# 47     gcta  0.117953             kidney

# %%
meta_analysis(df_plot["rg"], df_plot["rg_stderr"])
# Out:
# (0.9689764360438434, 0.011785327645629033)

# %%
meta_analysis(df_plot_new["rg"], df_plot_new["rg_stderr"])
# Out:
# (0.9677027993364267, 0.011667327741574753)

# %%
df_plot_new = df_plot.copy()

# %% [markdown]
# # Bar plots of the estimates

# %%
df_tmp = df_plot[(df_plot.snpset == "imputed") & (df_plot.hermodel == "mafukb")]

fig, ax = plt.subplots(figsize=(7, 1.25), dpi=150)

ax.bar(
    df_tmp["trait"],
    df_tmp["rg"],
    yerr=df_tmp["rg_stderr"] * 2,
    align="center",
    alpha=0.5,
    ecolor="black",
    edgecolor="black",
    capsize=0,
)

display_name = [
    f"{dict_trait_display_name[row.trait]} ({row.n_indiv})"
    for _, row in df_tmp.drop_duplicates(subset=["trait"]).iterrows()
]
ax.set_xticklabels(
    display_name,
    rotation=45,
    va="top",
    ha="right",
    fontsize=9,
)

ax.axhline(y=1.0, ls="--", color="r")
ax.axhline(y=0.0, ls="--", color="gray")
trans = mtrans.Affine2D().translate(5, 0)
for t in ax.get_xticklabels():
    t.set_transform(t.get_transform() + trans)

ax.set_ylabel("$r_g$", fontsize=15)
ax.set_title(
    f"Fisher's combined $p=${combine_pvalues(df_tmp.pval)[1]: .1g} (for $H_0: r_g = 1$)"
)
fig.show()

ax.set_ylim(0, 1.6)
ax.set_xlim(-0.8, 23.8)
plt.tight_layout()
# plt.savefig("results/genome-wide.pdf", bbox_inches="tight")
# Out:
# <ipython-input-6-3c66f1c328e2>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# <ipython-input-6-3c66f1c328e2>:42: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df_tbl = df_plot[(df_plot.snpset == "imputed") & (df_plot.hermodel == "mafukb")].drop(
    columns=["snpset", "hermodel", "category"]
)
df_tbl.to_csv("results/admix-corr.csv", index=False)
# meta-analysis results
meta_mean, meta_se = meta_analysis(df_tbl["rg"], df_tbl["rg_stderr"])

df_tbl = df_tbl.append(
    {
        "trait": "Meta-analysis",
        "n_indiv": 0,
        "rg": meta_mean,
        "rg_stderr": meta_se,
        "pval": stats.norm.cdf((meta_mean - 1) / meta_se),
    },
    ignore_index=True,
)

df_tbl["trait"] = df_tbl["trait"].apply(
    lambda x: dict_trait_display_name[x] if x in dict_trait_display_name else x
)
df_tbl["n_indiv"] = df_tbl["n_indiv"].astype(int)
df_tbl["rg"] = df_tbl["rg"].apply(lambda x: f"{x:.3f}")
df_tbl["rg_stderr"] = df_tbl["rg_stderr"].apply(lambda x: f"{x:.3f}")
df_tbl["pval"] = df_tbl["pval"].apply(lambda x: f"{x:.3f}")

df_tbl = df_tbl.rename(
    columns={
        "trait": "Phenotype",
        "n_indiv": "$N$",
        "rg": "$\widehat{r_g}$",
        "rg_stderr": "$\widehat{\text{s.e.}(r_g)}$",
        "pval": "$p$-value",
    }
)

# %%
print(df_tbl.to_latex(escape=False, index=False))
# Out:
# \begin{tabular}{lrlll}
# \toprule
#                Phenotype &   $N$ & $\widehat{r_g}$ & $\widehat{\text{s.e.}(r_g)}$ & $p$-value \\
# \midrule
#       C-reactive protein &  8521 &           0.983 &                        0.059 &     0.386 \\
#   White blood cell count &  8889 &           0.930 &                        0.077 &     0.182 \\
#                     MCHC &  3816 &           0.886 &                        0.196 &     0.280 \\
#           Platelet count &  8871 &           0.883 &                        0.109 &     0.141 \\
#                      HDL & 10248 &           0.909 &                        0.093 &     0.164 \\
#                      LDL &  9875 &           0.951 &                        0.104 &     0.319 \\
#            Triglycerides & 10217 &           0.882 &                        0.110 &     0.141 \\
#        Total cholesterol & 10300 &           0.697 &                        0.183 &     0.048 \\
#       Cigarettes per day &  7171 &           0.990 &                        0.126 &     0.468 \\
#       Coffee consumption & 11862 &           1.031 &                        0.076 &     0.656 \\
#               HbA$_{1c}$ &  1854 &           1.183 &                        0.209 &     0.810 \\
#          Fasting insulin &  7927 &           1.039 &                        0.078 &     0.690 \\
#          Fasting glucose &  9937 &           0.813 &                        0.277 &     0.250 \\
#          Type 2 diabetes & 15014 &           0.910 &                        0.138 &     0.256 \\
#              QT interval &  4196 &           1.066 &                        0.090 &     0.767 \\
#             QRS interval &  4185 &           1.155 &                        0.089 &     0.959 \\
#              PR interval &  4178 &           0.903 &                        0.204 &     0.317 \\
#  Systolic blood pressure & 11425 &           1.102 &                        0.071 &     0.922 \\
# Diastolic blood pressure & 11424 &           1.004 &                        0.212 &     0.508 \\
#             Hypertension & 17195 &           0.956 &                        0.104 &     0.336 \\
#                      WHR & 10307 &           1.000 &                        0.085 &     0.499 \\
#                   Height & 17286 &           0.921 &                        0.037 &     0.017 \\
#                      BMI & 17264 &           0.947 &                        0.047 &     0.129 \\
#                     eGFR &  8261 &           0.812 &                        0.162 &     0.123 \\
#            Meta-analysis &     0 &           0.969 &                        0.017 &     0.038 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Consistency of estimate with different assumed genetic architecture

# %%
df_tbl1 = df_plot[(df_plot.snpset == "imputed") & (df_plot.hermodel == "mafukb")].drop(
    columns=["snpset", "hermodel", "category"]
)
df_tbl2 = df_plot[(df_plot.snpset == "imputed") & (df_plot.hermodel == "gcta")].drop(
    columns=["snpset", "hermodel", "category"]
)

# %%
fig, axes = plt.subplots(figsize=(4.5, 2.5), dpi=150, ncols=2)

for i, (k, label) in enumerate(zip(["rg", "pval"], ["$\widehat{r_g}$", "$p$-value"])):
    axes[i].scatter(df_tbl1[k], df_tbl2[k], s=3)
    axes[i].set_xlabel(f"{label} (default)")
    axes[i].set_ylabel(f"{label} (GCTA)")

    lim = [
        min(df_tbl1[k].min(), df_tbl2[k].min()),
        max(df_tbl1[k].max(), df_tbl2[k].max()),
    ]

    # annotation
    axes[i].text(
        -0.2,
        1.1,
        string.ascii_lowercase[i],
        transform=axes[i].transAxes,
        size=12,
        weight="bold",
    )
    axes[i].plot([lim[0], lim[1]], [lim[0], lim[1]], "k--", alpha=0.2)

fig.tight_layout()
plt.savefig("results/real-genome-wide-assumption-robust.pdf", bbox_inches="tight")
