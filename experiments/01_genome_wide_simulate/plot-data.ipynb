# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

import matplotlib.pyplot as plt
import numpy as np
import json
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Properties of GRM

# %%
grm1 = np.load("./out/grm/imputed.K12.npy")[0:100, 0:100]
grm2 = np.load("./out/OLD/grm/all.K12.npy")[0:100, 0:100]

# %%
grm_imputed = np.load("./out/grm/snpset-imputed-hermodel-ldak.K1.npy")[0:100, 0:100]
grm_hm3 = np.load("./out/grm/snpset-hm3-hermodel-ldak.K1.npy")[0:100, 0:100]

# %%
import statsmodels.api as sm
import numpy as np

result = sm.OLS(grm_hm3.flatten(), sm.add_constant(grm_imputed.flatten())).fit()
print(result.params)
# Out:
# [9.13337965e-06 4.76977722e+00]

# %%
fig, ax = plt.subplots(figsize=(3, 3), dpi=150)
ax.scatter(grm_hm3.flatten(), grm_imputed.flatten(), s=2)
ax.set_xlabel("GRM on HM3 SNPs")
ax.set_ylabel("GRM on imputed SNPs")
# Out:
# Text(0, 0.5, 'GRM on imputed SNPs')
