# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

import matplotlib.pyplot as plt
import numpy as np
import json
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Properties of GRM

# %%
grm1 = np.load("./out/grm/hm3.K1.npy")[0:100, 0:100]

# %%
grm2 = np.load("./out/OLD/grm/hm3.K1.npy")[0:100, 0:100]

# %%
grm_all = np.load("./out/grm/all.K1.npy")[0:100, 0:100]
grm_hm3 = np.load("./out/grm/hm3.K1.npy")[0:100, 0:100]

# %%
import statsmodels.api as sm
import numpy as np

result = sm.OLS(grm_hm3.flatten(), sm.add_constant(grm_all.flatten())).fit()
print(result.params)
# Out:
# [1.77485005e-05 1.84180225e+00]

# %%
fig, ax = plt.subplots(figsize=(3, 3), dpi=150)
ax.scatter(grm_hm3.flatten(), grm_all.flatten(), s=2)
ax.set_xlabel("GRM on HM3 SNPs")
ax.set_ylabel("GRM on imputed SNPs")
# Out:
# Text(0, 0.5, 'GRM on imputed SNPs')
